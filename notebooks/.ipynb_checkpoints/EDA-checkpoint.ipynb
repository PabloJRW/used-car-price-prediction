# %%
import os
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_URL = "https://raw.githubusercontent.com/PabloJRW/used-car-price-prediction/main/datasets/raw/used_cars.csv"
df = pd.read_csv(DATA_URL, delimiter=',')
df.head(10)
# Out:
#       brand                            model  model_year       milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51,000 mi.
# 1   Hyundai                     Palisade SEL        2021   34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022   22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015   88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021    9,835 mi.
# 5     Acura                         ILX 2.4L        2016  136,397 mi.
# 6      Audi             S3 2.0T Premium Plus        2017   84,000 mi.
# 7       BMW                           740 iL        2001  242,000 mi.
# 8     Lexus                   RC 350 F Sport        2021   23,436 mi.
# 9     Tesla          Model X Long Range Plus        2020   34,000 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
# 5       Gasoline                                          2.4 Liter
# 6       Gasoline       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 7       Gasoline       282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 8       Gasoline      311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 9            NaN        534.0HP Electric Motor Electric Fuel System
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
# 5                  F                  Silver  Ebony.
# 6        6-Speed A/T                    Blue   Black
# 7                A/T                   Green   Green
# 8        6-Speed A/T                   Black   Black
# 9                A/T                   Black   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999
# 5                           None reported         NaN  $14,798
# 6                           None reported         Yes  $31,000
# 7                           None reported         Yes   $7,300
# 8                           None reported         Yes  $41,927
# 9                           None reported         Yes  $69,950

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
# ¿Cuántos valores únicos tiene cada variable categórica?
for col in df.select_dtypes('object'):
    print(f"{col.ljust(15)}: {df[col].nunique()}")
# Out:
# brand          : 57
# model          : 1898
# milage         : 2818
# fuel_type      : 7
# engine         : 1146
# transmission   : 62
# ext_col        : 319
# int_col        : 156
# accident       : 2
# clean_title    : 1
# price          : 1569

# %%
df2 = pd.DataFrame()

# %% [markdown]
# ### Price

# %%
# Eliminando caracteres y convirtiendo la variable 'price' a numérica
df['price'] = df['price'].str.replace("$", "").str.replace(",", "").astype(int)
df2['price'] = df['price']

# %%
sns.displot(df['price'])
plt.savefig(os.path.join('..','img','price'))
plt.xlabel('Precio')
plt.show()

# %%
df['price'].describe()
# Out:
# count    4.009000e+03
# mean     4.455319e+04
# std      7.871064e+04
# min      2.000000e+03
# 25%      1.720000e+04
# 50%      3.100000e+04
# 75%      4.999000e+04
# max      2.954083e+06
# Name: price, dtype: float64

# %%
df[df['price'] >= 500000].sample(5)
# Out:
#             brand               model  model_year      milage fuel_type  \
# 624   Rolls-Royce            Cullinan        2022     398 mi.  Gasoline
# 3046      Porsche     Carrera GT Base        2005   4,400 mi.  Gasoline
# 979   Lamborghini  Aventador SVJ Base        2019   6,929 mi.  Gasoline
# 1356  Lamborghini  Aventador SVJ Base        2021   6,987 mi.  Gasoline
# 693      Maserati   Quattroporte Base        2005  32,000 mi.  Gasoline
#
#                                              engine  \
# 624                6.7L V12 48V GDI DOHC Twin Turbo
# 3046  605.0HP 5.7L 10 Cylinder Engine Gasoline Fuel
# 979   759.0HP 6.5L 12 Cylinder Engine Gasoline Fuel
# 1356                         6.5L V12 48V MPFI DOHC
# 693    394.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
#
#                         transmission ext_col       int_col  \
# 624                8-Speed Automatic  Silver  Charles Blue
# 3046                     6-Speed M/T    Gray         Black
# 979                              A/T    Blue         Black
# 1356                         7-Speed       –      Nero Ade
# 693   Transmission w/Dual Shift Mode     Red         Beige
#
#                                     accident clean_title    price
# 624                            None reported         Yes   695000
# 3046                           None reported         Yes  1599000
# 979                            None reported         Yes   649999
# 1356                           None reported         Yes   749950
# 693   At least 1 accident or damage reported         Yes  2954083

# %%
plt.figure()
sns.displot(df[df['price'] <= 250000]['price'])
plt.xlabel('Precios')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ### Brand

# %%
# Cuántas marcas de autos?
df['brand'].nunique()
# Out:
# 57

# %%
brand_count = df['brand'].value_counts()

plt.figure(figsize=(12, 4))
sns.barplot(x=brand_count.index, y=brand_count.values)
plt.xticks(rotation=90)
plt.xlabel('Marcas')
plt.ylabel('Frecuencia')
plt.savefig(os.path.join('..','img','brand_dist'))
plt.show()

# %%
df['brand'].value_counts()
# Out:
# brand
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Audi             200
# Toyota           199
# Lexus            163
# Jeep             143
# Land             130
# Nissan           116
# Cadillac         107
# GMC               91
# RAM               91
# Dodge             90
# Tesla             87
# Kia               76
# Hyundai           72
# Mazda             64
# Acura             64
# Subaru            64
# Honda             63
# Volkswagen        59
# INFINITI          59
# Lincoln           52
# Jaguar            47
# Volvo             38
# Maserati          34
# Bentley           33
# MINI              33
# Buick             30
# Chrysler          28
# Lamborghini       26
# Mitsubishi        20
# Genesis           20
# Alfa              19
# Rivian            17
# Hummer            16
# Pontiac           15
# Ferrari           12
# Rolls-Royce       11
# Aston              9
# McLaren            6
# Scion              6
# FIAT               5
# Saturn             5
# Lotus              4
# Lucid              3
# Mercury            3
# Karma              2
# Saab               2
# Polestar           1
# Bugatti            1
# Plymouth           1
# smart              1
# Maybach            1
# Suzuki             1
# Name: count, dtype: int64

# %% [markdown]
# ### Model Year

# %%
plt.figure()
sns.displot(df['model_year'])
plt.savefig(os.path.join('..','img','model_year_fig'))
plt.xlabel('Año del modelo')
plt.ylabel('Frecuencia')
plt.show()

# %%
df['model_year'].describe()
# Out:
# count    4009.000000
# mean     2015.515590
# std         6.104816
# min      1974.000000
# 25%      2012.000000
# 50%      2017.000000
# 75%      2020.000000
# max      2024.000000
# Name: model_year, dtype: float64

# %%
# ¿Cuántos autos por año?
df['model_year'].value_counts()
# Out:
# model_year
# 2022    354
# 2021    350
# 2020    322
# 2018    315
# 2019    297
# 2016    268
# 2017    259
# 2015    228
# 2023    226
# 2014    181
# 2013    158
# 2012    141
# 2011    124
# 2008    113
# 2010    100
# 2007     98
# 2005     72
# 2009     72
# 2006     66
# 2004     60
# 2003     49
# 2001     34
# 2002     32
# 2000     17
# 1999     15
# 1998     11
# 1997      9
# 1993      9
# 1996      8
# 1994      7
# 2024      6
# 1995      6
# 1974      1
# 1992      1
# Name: count, dtype: int64

# %%
df2['model_year'] = df['model_year'].copy()

# %% [markdown]
# ### Milage

# %%
# Verificanco los valores de 'milage'
df['milage']
# Out:
# 0       51,000 mi.
# 1       34,742 mi.
# 2       22,372 mi.
# 3       88,900 mi.
# 4        9,835 mi.
#            ...
# 4004       714 mi.
# 4005    10,900 mi.
# 4006     2,116 mi.
# 4007    33,000 mi.
# 4008    43,000 mi.
# Name: milage, Length: 4009, dtype: object

# %%
# Se encuentra 'mi.' en todas las entradas de 'mi.'?
df['milage'].str.split().str[1].unique()
# Out:
# array(['mi.'], dtype=object)

# %%
# Extrayendo sólo los numeros, excluyendo 'mi'
df['milage'] = df['milage'].str.split().str[0]
# Convirtiendo la variable 'milage' a tipo numérico
df['milage'] = df['milage'].str.replace(",", "").astype(int)
df2['milage'] = df['milage'].copy()

# %%
sns.displot(df['milage'])
plt.xlabel('Millas')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.savefig(os.path.join('..','img','milage_fig'))
plt.show()

# %%
# Estadísticos de 'milage'
df['milage'].describe()
# Out:
# count      4009.000000
# mean      64717.551010
# std       52296.599459
# min         100.000000
# 25%       23044.000000
# 50%       52775.000000
# 75%       94100.000000
# max      405000.000000
# Name: milage, dtype: float64

# %% [markdown]
# ### Fuel Type

# %%
# Cuántos tipos de combustible se encuentran en el dataset?
[print(x) for x in df['fuel_type'].unique()]
# Out:
# E85 Flex Fuel
# Gasoline
# Hybrid
# nan
# Diesel
# Plug-In Hybrid
# –
# not supported
# [None, None, None, None, None, None, None, None]

# %%
# Características de los autos que funcionan con combustible 'E85 Flex Fuel'
df[df['fuel_type']=='E85 Flex Fuel'][['brand','model','model_year','milage','engine','price']].sample(10)
# Out:
#           brand                                 model  model_year  milage  \
# 3436       Ford                              F-150 XL        2018   52500
# 2746        GMC                             Yukon SLT        2014  142400
# 1725  Chevrolet                             Tahoe LTZ        2014  196300
# 2305       Audi                  Q5 2.0T Premium Plus        2015  118500
# 1740       Land  Rover Range Rover Sport Supercharged        2014  125000
# 2180       Ford                             F-250 XLT        2019  124000
# 1574  Chevrolet                     Silverado 2500 LT        2016   84421
# 863        Audi                       A4 2.0T Premium        2015   91403
# 1863   Chrysler                                 200 C        2015   44000
# 179        Ford                        Transit-350 XL        2018   95000
#
#                                                  engine  price
# 3436  395.0HP 5.0L 8 Cylinder Engine Flex Fuel Capab...  35000
# 2746  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...  13500
# 1725  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...  10995
# 2305  220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...  15400
# 1740  510.0HP 5.0L 8 Cylinder Engine Flex Fuel Capab...  22500
# 2180  385.0HP 6.2L 8 Cylinder Engine Flex Fuel Capab...  40100
# 1574  360.0HP 6.0L 8 Cylinder Engine Flex Fuel Capab...  36800
# 863            2.0L I4 16V GDI DOHC Turbo Flexible Fuel  14998
# 1863  295.0HP 3.6L V6 Cylinder Engine Flex Fuel Capa...  12700
# 179   275.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...  43000

# %%
# Características de los autos que funcionan con combustible 'Gasoline'
df[df['fuel_type']=='Gasoline'][['brand','model','model_year','milage','engine','price']].sample(10)
# Out:
#            brand                                          model  model_year  \
# 2981         Kia                                          Rio S        2021
# 2705         BMW                                       Z4 3.0si        2008
# 1407         BMW                                   Z4 sDrive28i        2016
# 3683      Jaguar                                       XK8 Base        1997
# 1913         Kia                                          K5 EX        2021
# 1827         BMW                                      X6 M Base        2018
# 3793  Volkswagen  Golf GTI 2.0T SE w/Performance Package 4-Door        2016
# 2105   Chevrolet                                     Camaro 2SS        2018
# 3055     Pontiac                                   Solstice GXP        2007
# 2125      Subaru                                Impreza Premium        2022
#
#       milage                                             engine  price
# 2981   67686       120.0HP 1.6L 4 Cylinder Engine Gasoline Fuel  15700
# 2705   59257  255.0HP 3.0L Straight 6 Cylinder Engine Gasoli...  18200
# 1407   59000       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  25000
# 3683   50000       290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel   6000
# 1913    8263       180.0HP 1.6L 4 Cylinder Engine Gasoline Fuel  29000
# 1827   54293       567.0HP 4.4L 8 Cylinder Engine Gasoline Fuel  49000
# 3793   59250       220.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  18999
# 2105   26000       455.0HP 6.2L 8 Cylinder Engine Gasoline Fuel  39000
# 3055   47000       260.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  13300
# 2125   10419  2L H-4 gasoline direct injection, DOHC, variab...  24998

# %%
df[df['fuel_type']=='Gasoline'][['engine']].sample(10)
# Out:
#                                                  engine
# 1600  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2626      333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 288       300.0HP 3.7L V6 Cylinder Engine Gasoline Fuel
# 2317       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 1906       383.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 3710      365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 760       315.0HP 2.7L V6 Cylinder Engine Gasoline Fuel
# 989       365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1631      312.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 406                               3.6L V6 24V MPFI DOHC

# %%
df[df['fuel_type']=='not supported']
# Out:
#        brand          model  model_year  milage      fuel_type  \
# 2894  Toyota  Mirai Limited        2021   44000  not supported
# 3700  Toyota     Mirai Base        2016   40000  not supported
#
#                                     engine transmission ext_col int_col  \
# 2894  182.0HP Electric Motor Hydrogen Fuel          A/T    Gray   Black
# 3700  151.0HP Electric Motor Hydrogen Fuel          A/T  Silver   Black
#
#            accident clean_title  price
# 2894  None reported         Yes  18500
# 3700  None reported         Yes   9500

# %%
df[df['fuel_type'].isna()][:10]
# Out:
#         brand                    model  model_year  milage fuel_type  \
# 9       Tesla  Model X Long Range Plus        2020   34000       NaN
# 44      Lucid        Air Grand Touring        2022    3552       NaN
# 68      Lucid        Air Grand Touring        2022    4900       NaN
# 92     Rivian    R1S Adventure Package        2023    2800       NaN
# 122    Rivian    R1S Adventure Package        2023    2500       NaN
# 129     Lucid                 Air Pure        2023    1300       NaN
# 155     Tesla      Model 3 Performance        2022   13079       NaN
# 189     Tesla      Model Y Performance        2023     500       NaN
# 225     Tesla             Model X Base        2023    8200       NaN
# 236  Polestar         2 Launch Edition        2021   12172       NaN
#
#                                           engine       transmission  \
# 9    534.0HP Electric Motor Electric Fuel System                A/T
# 44   536.0HP Electric Motor Electric Fuel System        1-Speed A/T
# 68   536.0HP Electric Motor Electric Fuel System        1-Speed A/T
# 92   835.0HP Electric Motor Electric Fuel System        1-Speed A/T
# 122  835.0HP Electric Motor Electric Fuel System                A/T
# 129  620.0HP Electric Motor Electric Fuel System                A/T
# 155  455.0HP Electric Motor Electric Fuel System                A/T
# 189  455.0HP Electric Motor Electric Fuel System        1-Speed A/T
# 225  670.0HP Electric Motor Electric Fuel System                A/T
# 236                                     Electric  1-Speed Automatic
#
#           ext_col   int_col       accident clean_title   price
# 9           Black     Black  None reported         Yes   69950
# 44            Red     Beige  None reported         Yes  119999
# 68            Red     Black  None reported         Yes   99000
# 92          White     Green  None reported         Yes   92000
# 122         Green     White  None reported         Yes   94000
# 129         Black      Gray            NaN         NaN   86900
# 155         Black     White  None reported         Yes   47000
# 189         Black     White  None reported         Yes   60000
# 225         Black     Black  None reported         Yes   93999
# 236  Thunder Gray  Charcoal  None reported         NaN   35999

# %%
# Convirtiendo valores 'nan' a 'electric'
df['fuel_type'] = df['fuel_type'].replace(np.nan, 'electric')
# Convirtiendo valores 'bot supported' a 'hydrogen'
df['fuel_type'] = df['fuel_type'].replace('not supported', 'hydrogen')

df2['fuel_type'] = df['fuel_type'].copy()
df[df['fuel_type']=="–"]
# Out:
#               brand                          model  model_year  milage  \
# 130        Chrysler               Pacifica Touring        2017   87305
# 257          Toyota              Land Cruiser Base        1993  231500
# 338           Mazda         Mazda3 s Grand Touring        2016   85000
# 491        Chrysler               Pacifica Touring        2017   63000
# 692           Honda                       Civic EX        1993   58981
# 855            Ford                         Bronco        1974    6217
# 923           Dodge                 Challenger R/T        2010  100100
# 995           Dodge       Challenger R/T Scat Pack        2019   43000
# 1063          Mazda         Mazda6 i Grand Touring        2016   83100
# 1083          Dodge                 Challenger R/T        2010   73000
# 1084      Chevrolet                       Sonic LT        2013  110000
# 1088          Mazda                MX-5 Miata Base        1992  125800
# 1134  Mercedes-Benz                   E-Class 400E        1993  106983
# 1269          Dodge       Challenger R/T Scat Pack        2016    7928
# 1294      Chevrolet     1500 Cheyenne Extended Cab        1995  120000
# 1355         Toyota              Land Cruiser Base        1996  233000
# 1615    Rolls-Royce                        Phantom        2023    1560
# 1643           Ford       Mustang EcoBoost Premium        2018   34000
# 1681          Acura                   Integra GS-R        1995  123000
# 1746         Nissan                     300ZX Base        1993  168000
# 1805        Mercury                      Capri XR2        1993  120644
# 1956         Nissan                     240SX Base        1996  160490
# 2026  Mercedes-Benz            E-Class D 2.5 Turbo        1993   70015
# 2103          Volvo                      850 Turbo        1995   94000
# 2115          Dodge             Challenger SRT 392        2016   37700
# 2303          Acura                       NSX Base        1993   75980
# 2447      Chevrolet                  1500 Cheyenne        1994  170443
# 2448         Jaguar                XJ6 Vanden Plas        1995   70000
# 2505          Dodge                Challenger SRT8        2011  106500
# 2574       Cadillac                   DeVille Base        1994   90000
# 2608           Jeep                     Wrangler S        1994   50750
# 2837        Porsche                    911 Carrera        1995   49900
# 2854         Nissan                Pickup Truck XE        1994   89144
# 3039       Cadillac                   DeVille Base        1994   85000
# 3068       Cadillac                   DeVille Base        1994   47000
# 3150           Ford                     Bronco XLT        1995  195000
# 3213           Ford       Mustang EcoBoost Premium        2019   31000
# 3413       Chrysler                    200 Limited        2017  100600
# 3469           Ford          F-250 XL SuperCab H/D        1993  115000
# 3572          Dodge            Challenger SRT8 392        2012   33700
# 3702            GMC  Sierra 1500 SLE1 Extended Cab        2008  187000
# 3918        Porsche          911 Carrera Cabriolet        1996   38000
# 3922          Mazda                     Protege DX        1993   94200
# 3952          Dodge          Ram 3500 Quad Cab DRW        2000  188000
# 3984         Toyota              Land Cruiser Base        1994  178416
#
#      fuel_type engine                    transmission             ext_col  \
# 130          –      –                     9-Speed A/T              Silver
# 257          –      –                             A/T               White
# 338          –      –                             A/T               Black
# 491          –      –                     9-Speed A/T               White
# 692          –      –                             A/T               White
# 855          –      –                               –  Dark Gray Metallic
# 923          –      –  Transmission w/Dual Shift Mode              Purple
# 995          –      –                     6-Speed M/T               Green
# 1063         –      –                             A/T               White
# 1083         –      –                             A/T               Black
# 1084         –      –                             A/T                Gray
# 1088         –      –                     5-Speed M/T                 Red
# 1134         –      –                     4-Speed A/T               White
# 1269         –      –                     6-Speed M/T                 Red
# 1294         –      –                     4-Speed A/T               White
# 1355         –      –                             A/T                Blue
# 1615         –      –                               –             Tempest
# 1643         –      –                             A/T                Blue
# 1681         –      –                     5-Speed M/T               White
# 1746         –      –                     5-Speed M/T               White
# 1805         –      –                     5-Speed M/T               Green
# 1956         –      –                     5-Speed M/T                Gray
# 2026         –      –                     4-Speed A/T                Gray
# 2103         –      –                             A/T               White
# 2115         –      –                     8-Speed A/T               Black
# 2303         –      –                             A/T              Silver
# 2447         –      –                             A/T                 Red
# 2448         –      –                             A/T                Gold
# 2505         –      –                     5-Speed A/T               White
# 2574         –      –                             A/T               Green
# 2608         –      –                     5-Speed M/T                Blue
# 2837         –      –                     6-Speed M/T              Silver
# 2854         –      –                             A/T                 Red
# 3039         –      –                             A/T               White
# 3068         –      –                             A/T               White
# 3150         –      –                             A/T                Blue
# 3213         –      –                     6-Speed M/T                Gray
# 3413         –      –                             A/T               Black
# 3469         –      –                             A/T                 Red
# 3572         –      –                     6-Speed M/T               Black
# 3702         –      –                     4-Speed A/T                 Red
# 3918         –      –  Transmission w/Dual Shift Mode                Blue
# 3922         –      –                             A/T                Gray
# 3952         –      –                             A/T              Silver
# 3984         –      –                             A/T               Green
#
#           int_col                                accident clean_title   price
# 130         Black                           None reported         Yes    9000
# 257          Gray                           None reported         Yes   29500
# 338         Black  At least 1 accident or damage reported         Yes   18500
# 491         Beige                           None reported         Yes   20000
# 692         Beige                           None reported         Yes    9599
# 855             –                           None reported         Yes  115000
# 923         Black                           None reported         Yes   17000
# 995         Black                           None reported         Yes   50000
# 1063        White                           None reported         Yes   17800
# 1083        Black                           None reported         Yes   17500
# 1084        Black                           None reported         Yes    7500
# 1088        Black                           None reported         Yes   11500
# 1134         Gray                           None reported         Yes   15300
# 1269          Red                           None reported         Yes   37500
# 1294        Brown  At least 1 accident or damage reported         Yes    6500
# 1355         Gray                           None reported         Yes    7500
# 1615  Cobalt Blue                           None reported         Yes  599995
# 1643         Gray  At least 1 accident or damage reported         Yes   25000
# 1681         Blue                           None reported         Yes   10999
# 1746        Black                           None reported         Yes    7000
# 1805         Gray                           None reported         Yes    4200
# 1956        Black                           None reported         Yes   15500
# 2026         Gray                           None reported         Yes   22500
# 2103        Black                           None reported         Yes    4500
# 2115        Black  At least 1 accident or damage reported         Yes   38000
# 2303        Black                           None reported         Yes   90200
# 2447            –  At least 1 accident or damage reported         Yes    6000
# 2448            –                           None reported         Yes   19000
# 2505        White  At least 1 accident or damage reported         Yes   22500
# 2574        Beige  At least 1 accident or damage reported         Yes    2990
# 2608         Gray                           None reported         Yes   15000
# 2837         Gray  At least 1 accident or damage reported         Yes   97993
# 2854         Gray                           None reported         Yes    5899
# 3039         Blue                           None reported         Yes    7900
# 3068         Blue                           None reported         Yes    5990
# 3150         Gray                           None reported         Yes   15000
# 3213        Black                           None reported         Yes   34700
# 3413        Black                           None reported         Yes   10000
# 3469         Gray                           None reported         Yes   21900
# 3572        Black                           None reported         Yes   33500
# 3702         Gray  At least 1 accident or damage reported         Yes    6100
# 3918         Gray                                     NaN         NaN   75000
# 3922            –  At least 1 accident or damage reported         Yes    2500
# 3952         Gray  At least 1 accident or damage reported         Yes   10000
# 3984        Beige                           None reported         Yes    9000

# %% [markdown]
# ### Engine

# %%
def extraer_caracteristicas_engine(engine):
    # Expresión regular para extraer la potencia 'hp'
    hp_pattern = r'(\d+\.\d+)HP'
    hp_matches = re.search(hp_pattern, engine)

    # Expresión regular para extraer la cilindrada 'L'
    cylinders_pattern = r'(\d+\.\d+)L'
    cylinders_matches = re.search(cylinders_pattern, engine)

    # Expresión regular para extraer el tipo de motor
    motor_pattern = r' (\w?\d+)'
    motor_matches = re.search(motor_pattern, engine)

    # Expresión regular para extraer el combustible
    fuel_pattern = r'(\w+\s?\w+\s?\w*) Fuel'
    fuel_matches = re.search(fuel_pattern, engine)

    # Asignar valores predeterminados en caso de no encontrar coincidencias
    hp = hp_matches.group(1) if hp_matches else None
    cylinders = cylinders_matches.group(1) if cylinders_matches else None
    motor = motor_matches.group(1) if motor_matches else None
    fuel = fuel_matches.group(1) if fuel_matches else None

    return hp, cylinders, motor, fuel

# %%
df['hp'], df['cylinders'], df['motor'], df['fuel_matches'] = zip(*df['engine'].apply(extraer_caracteristicas_engine))
df2['hp'], df2['cylinders'] = df['hp'], df['cylinders']

# %%
df.sample(5)
# Out:
#        brand                      model  model_year  milage fuel_type  \
# 2951    Ford               Explorer XLT        2014  127558  Gasoline
# 3902     BMW                  X5 M Base        2013   67000  Gasoline
# 3764    Audi  Q4 e-tron 50 Premium Plus        2022     250  electric
# 2748  Nissan                   Xterra S        2012   80000  Gasoline
# 2409  Nissan              Altima 2.5 SL        2012   91545  Gasoline
#
#                                              engine       transmission  \
# 2951                          3.5L V6 24V MPFI DOHC  6-Speed Automatic
# 3902   555.0HP 4.4L 8 Cylinder Engine Gasoline Fuel                A/T
# 3764    295.0HP Electric Motor Electric Fuel System        1-Speed A/T
# 2748  261.0HP 4.0L V6 Cylinder Engine Gasoline Fuel                A/T
# 2409   175.0HP 2.5L 4 Cylinder Engine Gasoline Fuel   CVT Transmission
#
#      ext_col         int_col                                accident  \
# 2951   Green  Charcoal Black                           None reported
# 3902  Silver           Black  At least 1 accident or damage reported
# 3764    Gray           Black                           None reported
# 2748   Black            Gray                           None reported
# 2409  Silver           Black                           None reported
#
#      clean_title  price     hp cylinders motor              fuel_matches
# 2951         Yes  13715   None       3.5    V6                      None
# 3902         Yes  24500  555.0       4.4     4  Cylinder Engine Gasoline
# 3764         Yes  52000  295.0      None  None   Electric Motor Electric
# 2748         Yes  14800  261.0       4.0     4  Cylinder Engine Gasoline
# 2409         Yes   8999  175.0       2.5     2  Cylinder Engine Gasoline

# %%
df['engine']
# Out:
# 0       300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1                                    3.8L V6 24V GDI DOHC
# 2                                          3.5 Liter DOHC
# 3       354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4                              2.0L I4 16V GDI DOHC Turbo
#                               ...
# 4004                     6.0L W12 48V PDI DOHC Twin Turbo
# 4005        349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006                                             Electric
# 4007        450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008         248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# Name: engine, Length: 4009, dtype: object

# %% [markdown]
# ### Transmission

# %%
# ¿Cuántos tipos de transmisón?
df['transmission'].nunique()
# Out:
# 62

# %%
# Transmisiones
df['transmission'].unique()
# Out:
# array(['6-Speed A/T', '8-Speed Automatic', 'Automatic', '7-Speed A/T',
#        'F', 'A/T', '8-Speed A/T', 'Transmission w/Dual Shift Mode',
#        '9-Speed Automatic', '6-Speed M/T', '10-Speed A/T', '9-Speed A/T',
#        '5-Speed A/T', '1-Speed A/T', 'Automatic CVT',
#        '7-Speed Automatic with Auto-Shift', 'CVT-F', 'M/T',
#        '6-Speed Automatic with Auto-Shift', '10-Speed Automatic',
#        'CVT Transmission', '4-Speed A/T', '6-Speed Automatic',
#        '4-Speed Automatic', '7-Speed M/T',
#        '8-Speed Automatic with Auto-Shift', '5-Speed Automatic',
#        '8-SPEED AT', '1-Speed Automatic', '5-Speed M/T', 'Manual',
#        '6-Speed Manual', 'Variable', '2', '7-Speed Manual',
#        'Automatic, 9-Spd 9G-Tronic', 'Automatic, 8-Spd',
#        'Automatic, 8-Spd Sport w/Sport & Manual Modes', '–',
#        'Auto, 6-Spd w/CmdShft', 'Transmission Overdrive Switch',
#        '7-Speed Automatic', 'Automatic, 8-Spd PDK Dual-Clutch',
#        'Automatic, 8-Spd M STEPTRONIC w/Drivelogic, Sport & Manual Modes',
#        'Automatic, 8-Spd Dual-Clutch', '6-Speed',
#        'Single-Speed Fixed Gear', 'Automatic, 10-Spd',
#        '2-Speed Automatic', '7-Speed',
#        'Automatic, 7-Spd S tronic Dual-Clutch', 'Manual, 6-Spd',
#        '6-Speed Electronically Controlled Automatic with O',
#        '6 Speed At/Mt', '8-SPEED A/T',
#        '10-Speed Automatic with Overdrive', '7-Speed DCT Automatic',
#        '9-Speed Automatic with Auto-Shift',
#        'SCHEDULED FOR OR IN PRODUCTION', '2-Speed A/T', '6 Speed Mt',
#        '8-Speed Manual'], dtype=object)

# %%
# Extrayendo las velocidades de la variable 'transmission'
df['speed'] = df['transmission'].str.extract(r'(\d+)')

df2['speed'] = df['speed'].copy()

# %%
def extraer_transmision(variable):
    """
    Esta función toma una variable que representa el tipo de transmisión de un vehículo
    y devuelve una categoría estandarizada (manual, automático, dual o 'other').
    """
    
    variable = variable.lower()
    tipos_de_transmision = {'manual': ['manual', 'mt', 'm/t'],
                            'automatic': ['automatic', 'a/t', 'at'],
                            'dual': ['dual', 'at/mt']}
    
    for tipo, etiquetas in tipos_de_transmision.items():
        if any(etiqueta in variable for etiqueta in etiquetas):
            return tipo
    
    return 'other'

# %%
# Aplicar la función para extraer el texto deseado y crear una nueva columna
df['transmission_'] = df['transmission'].apply(extraer_transmision)

df2['transmission'] = df['transmission_'].copy()

# %%
df.sample(5)
# Out:
#           brand                         model  model_year  milage fuel_type  \
# 1316    Porsche                   Taycan Base        2021    6785  electric
# 2554    Porsche                       911 GT3        2015   23700  Gasoline
# 890     Porsche                     Cayenne S        2013   92000  Gasoline
# 3452  Chevrolet  Silverado 1500 LT Trail Boss        2020   49000  Gasoline
# 2680       Ford            Thunderbird Deluxe        2002   40110  Gasoline
#
#                                                  engine  \
# 1316                                           Electric
# 2554  475.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# 890        400.0HP 4.8L 8 Cylinder Engine Gasoline Fuel
# 3452       355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel
# 2680       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
#
#                         transmission                ext_col int_col  \
# 1316               2-Speed Automatic  Gentian Blue Metallic   Black
# 2554  Transmission w/Dual Shift Mode                  Black   Black
# 890                      8-Speed A/T                  Green    Gray
# 3452                             A/T                  White   Black
# 2680                             A/T                 Yellow   Black
#
#            accident clean_title   price     hp cylinders motor  \
# 1316  None reported         NaN  108900   None      None  None
# 2554  None reported         Yes  144940  475.0       3.8     3
# 890   None reported         Yes   23000  400.0       4.8     4
# 3452  None reported         Yes   44900  355.0       5.3     5
# 2680  None reported         Yes   18500  252.0       3.9     3
#
#                   fuel_matches speed transmission_
# 1316                      None     2     automatic
# 2554  Cylinder Engine Gasoline   NaN          dual
# 890   Cylinder Engine Gasoline     8     automatic
# 3452  Cylinder Engine Gasoline   NaN     automatic
# 2680  Cylinder Engine Gasoline   NaN     automatic

# %% [markdown]
# ### Accident

# %%
# ¿Cuántos valores únicos?
df['accident'].nunique()
# Out:
# 2

# %%
# Valores únicos
df['accident'].unique()
# Out:
# array(['At least 1 accident or damage reported', 'None reported', nan],
#       dtype=object)

# %%
# Convierto los valores nulos a 'None reported'
df['accident'] = df['accident'].fillna('None reported')
df2['accident'] = df['accident'].copy()

sns.barplot(df['accident'].value_counts())
plt.xticks(ticks=['None reported','At least 1 accident or damage reported'], labels=['Ninguno', 'Al menos 1'])
plt.xlabel('Accidente o Daño')
plt.ylabel('Frecuencia')
plt.show()

# %%
# ¿Cuántos accidentes o daños?
df['accident'].value_counts()
# Out:
# accident
# None reported                             3023
# At least 1 accident or damage reported     986
# Name: count, dtype: int64

# %%
# Porcentaje de autos accidentados
(df['accident'].value_counts() / df['accident'].count() * 100).round(1)
# Out:
# accident
# None reported                             75.4
# At least 1 accident or damage reported    24.6
# Name: count, dtype: float64

# %% [markdown]
# ### Clean Title

# %%
# ¿Cuántos valores únicos?
df['clean_title'].nunique(dropna=False)
# Out:
# 2

# %%
df['clean_title'].value_counts(dropna=False)
# Out:
# clean_title
# Yes    3413
# NaN     596
# Name: count, dtype: int64

# %%
(df['clean_title'].value_counts() / df['clean_title'].count() * 100).round(1)
# Out:
# clean_title
# Yes    100.0
# Name: count, dtype: float64

# %%
# Reemplazo valores nulos por 'no'
df['clean_title'].fillna('no', inplace=True)
df2['clean_title'] = df['clean_title'].copy()

# %%
sns.barplot(df['clean_title'].value_counts())
plt.xticks(ticks=['Yes', 'no'], labels=['Sí', 'No'])
plt.xlabel('Titulo Limpio')
plt.ylabel('Frecuencia')
plt.savefig(os.path.join('..','img','title_fig'))
plt.show()

# %%
df2
# Out:
#        price  model_year  milage      fuel_type     hp cylinders speed  \
# 0      10300        2013   51000  E85 Flex Fuel  300.0       3.7     6
# 1      38005        2021   34742       Gasoline   None       3.8     8
# 2      54598        2022   22372       Gasoline   None      None   NaN
# 3      15500        2015   88900         Hybrid  354.0       3.5     7
# 4      34999        2021    9835       Gasoline   None       2.0     8
# ...      ...         ...     ...            ...    ...       ...   ...
# 4004  349950        2023     714       Gasoline   None       6.0     8
# 4005   53900        2022   10900       Gasoline  349.0       3.0   NaN
# 4006   90998        2022    2116       electric   None      None   NaN
# 4007   62999        2020   33000       Gasoline  450.0       3.5   NaN
# 4008   40000        2020   43000       Gasoline  248.0       2.0   NaN
#
#      transmission                                accident clean_title
# 0       automatic  At least 1 accident or damage reported         Yes
# 1       automatic  At least 1 accident or damage reported         Yes
# 2       automatic                           None reported          no
# 3       automatic                           None reported         Yes
# 4       automatic                           None reported          no
# ...           ...                                     ...         ...
# 4004    automatic                           None reported         Yes
# 4005         dual                           None reported         Yes
# 4006    automatic                           None reported          no
# 4007    automatic                           None reported         Yes
# 4008    automatic  At least 1 accident or damage reported         Yes
#
# [4009 rows x 10 columns]
